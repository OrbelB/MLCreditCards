# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("./clean_data/creditcard_application_clean_data.csv") 
# reading cleaned data

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Unnamed: 0       ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  ANNUAL_INCOME  \
# 0           0  5008804             1                1         0.2587
# 1           1  5008805             1                1         0.2587
# 2           2  5008806             1                1         0.0552
# 3           3  5008808             0                1         0.1570
# 4           4  5008809             0                1         0.1570
#
#    NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  AGE_YEARS  \
# 0                 4                    1                  4       0.32
# 1                 4                    1                  4       0.32
# 2                 4                    4                  1       0.58
# 3                 0                    4                  1       0.52
# 4                 0                    4                  1       0.52
#
#    EMPLOYMENT_LENGTH  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# ...

# %%
df
# Out:
#        Unnamed: 0       ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  ANNUAL_INCOME  \
# 0               0  5008804             1                1         0.2587
# 1               1  5008805             1                1         0.2587
# 2               2  5008806             1                1         0.0552
# 3               3  5008808             0                1         0.1570
# 4               4  5008809             0                1         0.1570
# ...           ...      ...           ...              ...            ...
# 36452       36452  5149828             1                1         0.1860
# 36453       36453  5149834             0                1         0.0843
# 36454       36454  5149838             0                1         0.0843
# 36455       36455  5150049             0                1         0.1657
# 36456       36456  5150337             0                1         0.0552
#
#        NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  AGE_YEARS  \
# ...

# %%
sns.histplot(data=df, x="AGE_YEARS", bins=20, stat='proportion').set(title='Age proportions')
# Out:
# [Text(0.5, 1.0, 'Age proportions')]

# %%
sns.histplot(data=df, x="EMPLOYMENT_LENGTH", bins=20, stat='proportion').set(title='Employment length proportions')
# Out:
# [Text(0.5, 1.0, 'Employment length proportions')]

# %%
sns.histplot(data=df, x="ANNUAL_INCOME", bins=30, stat='proportion').set(title='Anuual income proportions')
# Out:
# [Text(0.5, 1.0, 'Anuual income proportions')]

# %%
vplot = sns.violinplot(data=df, x="ANNUAL_INCOME")
vplot.set(ylabel='Counts',title='Annual income counts') # setting title and y-label
# Out:
# [Text(0, 0.5, 'Counts'), Text(0.5, 1.0, 'Annual income counts')]

# %%
sns.boxplot(data=df, x="ANNUAL_INCOME", y='NAME_HOUSING_TYPE', orient='h').set(title='Anuual income vs housing type')
#if we dont mention the orient='h' attribute, the graph results are plotted vertically, instead of horizontal.
# Out:
# [Text(0.5, 1.0, 'Anuual income vs housing type')]

# %%
sns.violinplot(data=df, x="ANNUAL_INCOME", y='NAME_EDUCATION_TYPE', orient='h').set(title='Annual income vs Education type')
# Out:
# [Text(0.5, 1.0, 'Annual income vs Education type')]

# %%
sns.scatterplot(data=df, x="AGE_YEARS", y='ANNUAL_INCOME').set(title='Age vs Anuual income')
# Out:
# [Text(0.5, 1.0, 'Age vs Anuual income')]

# %%
df['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# 4    24777
# 1     9864
# 2     1410
# 3      374
# 0       32
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
ax = plt.figure(figsize=(10,12))
ax.set_facecolor((1, 1, 1))

a = (df['NAME_EDUCATION_TYPE']==4).sum()
b = (df['NAME_EDUCATION_TYPE']==1).sum()
c = (df['NAME_EDUCATION_TYPE']==2).sum()
d = (df['NAME_EDUCATION_TYPE']==3).sum()
e = (df['NAME_EDUCATION_TYPE']==0).sum()

piedata = np.array([a, b, c, d, e])
colors = sns.color_palette('hls',8)
labels = ['4', '1', '2', '3' , '0']
plt.pie(piedata, labels = labels, colors=colors)
plt.legend(title = 'Education types')
plt.title("Education")
# Out:
# Text(0.5, 1.0, 'Education')

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# 1    32548
# 5     1776
# 2     1128
# 4      575
# 3      262
# 0      168
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
ax = plt.figure(figsize=(10,12))
ax.set_facecolor((1, 1, 1))

a = (df['NAME_HOUSING_TYPE']==1).sum()
b = (df['NAME_HOUSING_TYPE']==5).sum()
c = (df['NAME_HOUSING_TYPE']==2).sum()
d = (df['NAME_HOUSING_TYPE']==4).sum()
e = (df['NAME_HOUSING_TYPE']==3).sum()
f = (df['NAME_HOUSING_TYPE']==0).sum()

piedata = np.array([a, b, c, d, e, f])
colors = sns.color_palette('hls',8)
labels = ['1', '5' ,'2' ,'4' ,'3', '0']
plt.pie(piedata, labels = labels, colors=colors)
plt.legend(title = 'Housing types')
plt.title("Housing")
# Out:
# Text(0.5, 1.0, 'Housing')

# %%
fig, ax= plt.subplots(nrows= 3, ncols = 3, figsize= (20,10))

# plt.xticks(np.arange(step=1))
sns.scatterplot(x='ID', y='NAME_HOUSING_TYPE', data=df, ax=ax[0][0], color=sns.color_palette('hls',8)[0])
sns.scatterplot(x='ID', y='ANNUAL_INCOME', data=df, ax=ax[0][1], color=sns.color_palette('hls',8)[1])
sns.scatterplot(x='ID', y='AGE_YEARS', data=df, ax=ax[0][2], color=sns.color_palette('hls',8)[2])

sns.scatterplot(x='ID', y='EMPLOYMENT_LENGTH', data=df, ax=ax[1][0], color=sns.color_palette('hls',8)[3])
sns.scatterplot(x='ID', y='FLAG_MOBIL', data=df, ax=ax[1][1], color=sns.color_palette('hls',8)[4])
sns.scatterplot(x='ID', y='FLAG_WORK_PHONE', data=df, ax=ax[1][2], color=sns.color_palette('hls',8)[5])

sns.scatterplot(x='ID', y='FLAG_PHONE', data=df, ax=ax[2][0], color=sns.color_palette('hls',8)[6])
sns.scatterplot(x='ID', y='FLAG_EMAIL', data=df, ax=ax[2][1], color=sns.color_palette('hls',8)[7])
sns.scatterplot(x='ID', y='NAME_INCOME_TYPE', data=df, ax=ax[2][2], color=sns.color_palette('hls',8)[3])
# Out:
# <AxesSubplot:xlabel='ID', ylabel='NAME_INCOME_TYPE'>

# %%
ax = plt.figure(figsize=(10,12))
ax.set_facecolor((1, 1, 1))
badclients = df['STATUS']==1
badclients = badclients.sum()
goodclients = df['STATUS']==0
goodclients = goodclients.sum()
piedata = np.array([goodclients, badclients])
colors = sns.color_palette('hls',8)[4:7]
labels = ['Good client','Bad client']
datapie = df['STATUS']
plt.pie(piedata, labels = labels, colors=colors)
plt.legend(title = 'Clients')

# %%
sns.pairplot(df.drop(['ID', 'Unnamed: 0'], axis=1))
# remove Unnamed: 0 later on as in the latest version the indices are excluded while exporting
