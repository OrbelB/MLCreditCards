# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("./clean_data/creditcard_application_clean_data.csv")

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Unnamed: 0       ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  ANNUAL_INCOME  \
# 0           0  5008804             1                1         0.2587
# 1           1  5008805             1                1         0.2587
# 2           2  5008806             1                1         0.0552
# 3           3  5008808             0                1         0.1570
# 4           4  5008809             0                1         0.1570
#
#    NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  AGE_YEARS  \
# 0                 4                    1                  4       0.32
# 1                 4                    1                  4       0.32
# 2                 4                    4                  1       0.58
# 3                 0                    4                  1       0.52
# 4                 0                    4                  1       0.52
#
#    EMPLOYMENT_LENGTH  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# ...

# %%
data
# Out:
#        Unnamed: 0       ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  ANNUAL_INCOME  \
# 0               0  5008804             1                1         0.2587
# 1               1  5008805             1                1         0.2587
# 2               2  5008806             1                1         0.0552
# 3               3  5008808             0                1         0.1570
# 4               4  5008809             0                1         0.1570
# ...           ...      ...           ...              ...            ...
# 36452       36452  5149828             1                1         0.1860
# 36453       36453  5149834             0                1         0.0843
# 36454       36454  5149838             0                1         0.0843
# 36455       36455  5150049             0                1         0.1657
# 36456       36456  5150337             0                1         0.0552
#
#        NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  AGE_YEARS  \
# ...

# %%
sns.histplot(data=data, x="AGE_YEARS", bins=20, stat='proportion')
# Out:
# <AxesSubplot:xlabel='AGE_YEARS', ylabel='Proportion'>

# %%
sns.histplot(data=data, x="EMPLOYMENT_LENGTH", bins=20, stat='proportion')
# Out:
# <AxesSubplot:xlabel='EMPLOYMENT_LENGTH', ylabel='Proportion'>

# %%
sns.histplot(data=data, x="ANNUAL_INCOME", bins=30, stat='proportion')
# Out:
# <AxesSubplot:xlabel='ANNUAL_INCOME', ylabel='Proportion'>

# %%
vplot = sns.violinplot(data=data, x="ANNUAL_INCOME")
vplot.set(ylabel='Counts')
# Out:
# [Text(0, 0.5, 'Counts')]

# %%
sns.boxplot(data=data, x="ANNUAL_INCOME", y='NAME_HOUSING_TYPE', orient='h')
#if we dont mention the orient='h' attribute, the graph results are plotted vertically, instead of horizontal.
# Out:
# <AxesSubplot:xlabel='ANNUAL_INCOME', ylabel='NAME_HOUSING_TYPE'>

# %%
sns.violinplot(data=data, x="ANNUAL_INCOME", y='NAME_EDUCATION_TYPE', orient='h')
# Out:
# <AxesSubplot:xlabel='ANNUAL_INCOME', ylabel='NAME_EDUCATION_TYPE'>

# %%
sns.scatterplot(data=data, x="AGE_YEARS", y='ANNUAL_INCOME')
# Out:
# <AxesSubplot:xlabel='AGE_YEARS', ylabel='ANNUAL_INCOME'>

# %%
fig, ax= plt.subplots(nrows= 3, ncols = 3, figsize= (14,6))

# plt.xticks(np.arange(step=1))
sns.scatterplot(x='ID', y='NAME_HOUSING_TYPE', data=data, ax=ax[0][0], color=sns.color_palette('hls',8)[0])
sns.scatterplot(x='ID', y='ANNUAL_INCOME', data=data, ax=ax[0][1], color=sns.color_palette('hls',8)[1])
sns.scatterplot(x='ID', y='AGE_YEARS', data=data, ax=ax[0][2], color=sns.color_palette('hls',8)[2])

sns.scatterplot(x='ID', y='EMPLOYMENT_LENGTH', data=data, ax=ax[1][0], color=sns.color_palette('hls',8)[3])
sns.scatterplot(x='ID', y='FLAG_MOBIL', data=data, ax=ax[1][1], color=sns.color_palette('hls',8)[4])
sns.scatterplot(x='ID', y='FLAG_WORK_PHONE', data=data, ax=ax[1][2], color=sns.color_palette('hls',8)[5])

sns.scatterplot(x='ID', y='FLAG_PHONE', data=data, ax=ax[2][0], color=sns.color_palette('hls',8)[6])
sns.scatterplot(x='ID', y='FLAG_EMAIL', data=data, ax=ax[2][1], color=sns.color_palette('hls',8)[7])
sns.scatterplot(x='ID', y='NAME_INCOME_TYPE', data=data, ax=ax[2][2], color=sns.color_palette('hls',8)[3])
# Out:
# <AxesSubplot:xlabel='ID', ylabel='NAME_INCOME_TYPE'>

# %%
ax = plt.figure(figsize=(10,12))
ax.set_facecolor((1, 1, 1))
badclients = data['STATUS']==0
badclients = m.sum()
goodclients = data['STATUS']==1
goodclients = goodclients.sum()
piedata = np.array([m,n])
colors = sns.color_palette('hls',8)[4:7]
labels = ['Good client','Bad client']
datapie = data['STATUS']
plt.pie(y, labels = label, colors=colors)
plt.legend(title = 'Clients')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       2 ax.set_facecolor((1, 1, 1))
#       3 badclients = data['STATUS']==0
# ----> 4 badclients = m.sum()
#       5 goodclients = data['STATUS']==1
#       6 goodclients = goodclients.sum()
#
# NameError: name 'm' is not defined
